# %%
import numpy as np
import gymnasium as gym
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import matplotlib
from IPython.display import HTML

import torch
import torch.nn as nn
import torch.nn.functional as F

from src.CNN import CNNActionValue
from src.evaluate import evaluate
import src.DQN as DQN
from src.Preprocess import preprocess, ImageEnv

# %%
env = gym.make('CarRacing-v0', continuous=False)
print("Observation space: ", env.observation_space)
print("Action space: ", env.action_space)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 env = gym.make('CarRacing-v0', continuous=False)
#       2 print("Observation space: ", env.observation_space)
#       3 print("Action space: ", env.action_space)
#
# File c:\Users\jjk21\anaconda3\envs\dqn\lib\site-packages\gym\envs\registration.py:235, in make(id, **kwargs)
#     234 def make(id, **kwargs):
# --> 235     return registry.make(id, **kwargs)
#
# File c:\Users\jjk21\anaconda3\envs\dqn\lib\site-packages\gym\envs\registration.py:129, in EnvRegistry.make(self, path, **kwargs)
#     127     logger.info("Making new env: %s", path)
#     128 spec = self.spec(path)
# --> 129 env = spec.make(**kwargs)
#     130 return env
#
# File c:\Users\jjk21\anaconda3\envs\dqn\lib\site-packages\gym\envs\registration.py:89, in EnvSpec.make(self, **kwargs)
#      87     env = self.entry_point(**_kwargs)
#      88 else:
# ---> 89     cls = load(self.entry_point)
#      90     env = cls(**_kwargs)
#      92 # Make the environment aware of which spec it came from.
#
# File c:\Users\jjk21\anaconda3\envs\dqn\lib\site-packages\gym\envs\registration.py:28, in load(name)
#      26 mod_name, attr_name = name.split(":")
#      27 mod = importlib.import_module(mod_name)
# ---> 28 fn = getattr(mod, attr_name)
#      29 return fn
#
# AttributeError: module 'gym.envs.box2d' has no attribute 'CarRacing'

# %%
s, info = env.reset()
print(s.shape)

frames = []
for i in range(50):
    action = [0.0, 0.0, 0.0]
    s, r, terminated, truncated, info = env.step(0)  # 0-th action is no_op action
    frames.append(s)

# Create animation
fig = plt.figure(figsize=(5, 5))
plt.axis('off')
im = plt.imshow(frames[0])
def animate(i):
    im.set_array(frames[i])
    return im,
anim = FuncAnimation(fig, animate, frames=len(frames))
HTML(anim.to_jshtml())
# Out:
# (96, 96, 3)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 7
#       5 for i in range(50):
#       6     action = [0.0, 0.0, 0.0]
# ----> 7     s, r, terminated, truncated, info = env.step(0)  # 0-th action is no_op action
#       8     frames.append(s)
#      10 # Create animation
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\envs\box2d\car_racing.py:544, in CarRacing.step(self, action)
#     542 assert self.car is not None
#     543 if action is not None:
# --> 544     action = action.astype(np.float64)
#     545     if self.continuous:
#     546         self.car.steer(-action[0])
#
# AttributeError: 'int' object has no attribute 'astype'

# %%
env = gym.make('CarRacing-v3', continuous=False)
env = ImageEnv(env)

s, _ = env.reset()
print("The shape of an observation: ", s.shape)

fig, axes = plt.subplots(1, 4, figsize=(20, 5))
for i in range(4):
    axes[i].imshow(s[i], cmap='gray')
    axes[i].axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 env = gym.make('CarRacing-v3', continuous=False)
#       2 env = ImageEnv(env)
# ----> 4 s, _ = env.reset()
#       5 print("The shape of an observation: ", s.shape)
#       7 fig, axes = plt.subplots(1, 4, figsize=(20, 5))
#
# File c:\Users\jjk21\Desktop\DQN-Car-Racing-master\DQN-Car-Racing-master\src\Preprocess.py:33, in ImageEnv.reset(self)
#      31 # Do nothing for the next `self.initial_no_op` steps
#      32 for i in range(self.initial_no_op):
# ---> 33     s, r, terminated, truncated, info = self.env.step(0)
#      35 # Convert a frame to 84 X 84 gray scale one
#      36 s = preprocess(s)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\core.py:322, in Wrapper.step(self, action)
#     318 def step(
#     319     self, action: WrapperActType
#     320 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     321     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 322     return self.env.step(action)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\wrappers\common.py:283, in PassiveEnvChecker.step(self, action)
#     281 if self.checked_step is False:
#     282     self.checked_step = True
# --> 283     return env_step_passive_checker(self.env, action)
#     284 else:
#     285     return self.env.step(action)
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\utils\passive_env_checker.py:207, in env_step_passive_checker(env, action)
#     205 """A passive check for the environment step, investigating the returning data then returning the data unchanged."""
#     206 # We don't check the action as for some environments then out-of-bounds values can be given
# --> 207 result = env.step(action)
#     208 assert isinstance(
#     209     result, tuple
#     210 ), f"Expects step result to be a tuple, actual type: {type(result)}"
#     211 if len(result) == 4:
#
# File c:\Users\jjk21\anaconda3\envs\kookmin\lib\site-packages\gymnasium\envs\box2d\car_racing.py:544, in CarRacing.step(self, action)
#     542 assert self.car is not None
#     543 if action is not None:
# --> 544     action = action.astype(np.float64)
#     545     if self.continuous:
#     546         self.car.steer(-action[0])
#
# AttributeError: 'int' object has no attribute 'astype'

# %%
env = gym.make('CarRacing-v2', continuous=False)
env = ImageEnv(env)

max_steps = int(1e5)
eval_interval = 100
state_dim = (4, 84, 84)
action_dim = env.action_space.n

agent = DQN.DQN(state_dim, action_dim)

# %%
def evaluate(n_evals=5):
    eval_env = gym.make('CarRacing-v2', continuous=False)
    eval_env = ImageEnv(eval_env)
    
    scores = 0
    for i in range(n_evals):
        (s, _), done, ret = eval_env.reset(), False, 0
        while not done:
            a = agent.act(s, training=False)
            s_prime, r, terminated, truncated, info = eval_env.step(a)
            s = s_prime
            ret += r
            done = terminated or truncated
        scores += ret
    return np.round(scores / n_evals, 4)

# %%
from IPython.display import clear_output

history = {'Step': [], 'AvgReturn': []}

(s, _) = env.reset()
while True:
    a = agent.act(s)
    s_prime, r, terminated, truncated, info = env.step(a)
    result = agent.process((s, a, r, s_prime, terminated))  # You can track q-losses over training from `result` variable.
    
    s = s_prime
    if terminated or truncated:
        s, _ = env.reset()
        
    if agent.total_steps % eval_interval == 0:
        ret = evaluate()
        history['Step'].append(agent.total_steps)
        history['AvgReturn'].append(ret)
        
        clear_output()
        plt.figure(figsize=(8, 5))
        plt.plot(history['Step'], history['AvgReturn'], 'r-')
        plt.xlabel('Step', fontsize=16)
        plt.ylabel('AvgReturn', fontsize=16)
        plt.xticks(fontsize=14)
        plt.yticks(fontsize=14)
        plt.grid(axis='y')
        plt.show()
        
        torch.save(agent.network.state_dict(), 'dqn.pt')
    
    if agent.total_steps > max_steps:
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5f11ce493c11> in <module>
#      14
#      15     if agent.total_steps % eval_interval == 0:
# ---> 16         ret = evaluate()
#      17         history['Step'].append(agent.total_steps)
#      18         history['AvgReturn'].append(ret)
#
# <ipython-input-6-c36717a53e0c> in evaluate(n_evals)
#       8         while not done:
#       9             a = agent.act(s, training=False)
# ---> 10             s_prime, r, terminated, truncated, info = eval_env.step(a)
#      11             s = s_prime
#      12             ret += r
#
# ~\Desktop\DQN - 복사본\src\Preprocess.py in step(self, action)
#      44         reward = 0
#      45         for _ in range(self.skip_frames):
# ---> 46             s, r, terminated, truncated, info = self.env.step(action)
#      47             reward += r
#      48             if terminated or truncated:
#
# ~\anaconda3\envs\DQN\lib\site-packages\gymnasium\wrappers\time_limit.py in step(self, action)
#      55
#      56         """
# ---> 57         observation, reward, terminated, truncated, info = self.env.step(action)
#      58         self._elapsed_steps += 1
#      59
#
# ~\anaconda3\envs\DQN\lib\site-packages\gymnasium\wrappers\order_enforcing.py in step(self, action)
#      54         if not self._has_reset:
#      55             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56         return self.env.step(action)
#      57
#      58     def reset(self, **kwargs):
#
# ~\anaconda3\envs\DQN\lib\site-packages\gymnasium\wrappers\env_checker.py in step(self, action)
#      47             return env_step_passive_checker(self.env, action)
#      48         else:
# ---> 49             return self.env.step(action)
#      50
#      51     def reset(self, **kwargs):
#
# ~\anaconda3\envs\DQN\lib\site-packages\gymnasium\envs\box2d\car_racing.py in step(self, action)
#     551         self.t += 1.0 / FPS
#     552
# --> 553         self.state = self._render("state_pixels")
#     554
#     555         step_reward = 0
#
# ~\anaconda3\envs\DQN\lib\site-packages\gymnasium\envs\box2d\car_racing.py in _render(self, mode)
#     645             return self._create_image_array(self.surf, (VIDEO_W, VIDEO_H))
#     646         elif mode == "state_pixels":
# --> 647             return self._create_image_array(self.surf, (STATE_W, STATE_H))
#     648         else:
#     649             return self.isopen
#
# ~\anaconda3\envs\DQN\lib\site-packages\gymnasium\envs\box2d\car_racing.py in _create_image_array(self, screen, size)
#     776
#     777     def _create_image_array(self, screen, size):
# --> 778         scaled_screen = pygame.transform.smoothscale(screen, size)
#     779         return np.transpose(
#     780             np.array(pygame.surfarray.pixels3d(scaled_screen)), axes=(1, 0, 2)
#
# KeyboardInterrupt:

# %%
eval_env = gym.make('CarRacing-v2', continuous=False, render_mode='rgb_array')
eval_env = ImageEnv(eval_env)

frames = []
scores = 0
(s, _), done, ret = eval_env.reset(), False, 0
while not done:
    frames.append(eval_env.render())
    a = agent.act(s, training=False)
    s_prime, r, terminated, truncated, info = eval_env.step(a)
    s = s_prime
    ret += r
    done = terminated or truncated
scores += ret

# %%
import matplotlib.animation as animation
fig = plt.figure()
ims = []

for frame in frames:
    im = plt.imshow(frame, animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=50, blit=True)

# 애니메이션을 저장
ani.save('car_racing_result.gif', writer='pillow')

plt.show()
